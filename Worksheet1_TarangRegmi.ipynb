# %% [markdown]
# **2.1  Exercise - 1:**
# 1. Read and display the image.
#
# • Read the image using the Pillow library and display it.
#
# • You can also use matplotlib to display the image.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from PIL import Image
# display image in colab
image_colored = Image.open("/content/drive/MyDrive/AI and ML/Workshop1/Leena_image.png")
display(image_colored)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=366x357>

# %% [markdown]
# 2. Display only the top left corner of 100x100 pixels.
#
# • Extract the top-left corner of the image (100x100 pixels) and display it using NumPy and
# Array Indexing.

# %%
import numpy as np
img = Image.open("/content/drive/MyDrive/AI and ML/Workshop1/Leena_image.png")

# %%
img_np = np.array(img)

# Extract the top-left corner (100x100 pixels)
cropped_image = img_np[:100, :100]
# Display the cropped image
display(cropped_image)
# Out:
# array([[[225, 127, 110],
#         [224, 130, 106],
#         [226, 130, 105],
#         ...,
#         [206,  96,  89],
#         [207,  95,  92],
#         [208,  99,  93]],
#
#        [[225, 130, 110],
#         [224, 128, 104],
#         [224, 130, 114],
#         ...,
#         [207,  95,  93],
#         [208,  95,  91],
#         [207,  98,  91]],
#
#        [[223, 128, 105],
#         [223, 133, 114],
#         [224, 129, 111],
#         ...,
#         [209,  96,  95],
#         [209,  95,  93],
#         [209,  98,  91]],
#
#        ...,
#
#        [[172,  62,  77],
#         [169,  58,  78],
#         [170,  60,  74],
#         ...,
#         [202,  79,  78],
#         [196,  90,  94],
#         [197,  91,  94]],
#
#        [[168,  64,  76],
#         [167,  64,  73],
#         [169,  67,  82],
#         ...,
#         [198,  81,  81],
#         [207, 102,  88],
#         [210, 100,  86]],
#
#        [[172,  64,  78],
#         [171,  68,  81],
#         [170,  70,  82],
#         ...,
#         [207, 102,  94],
#         [214,  92,  83],
#         [211,  90,  85]]], dtype=uint8)

# %% [markdown]
# 3. Show the three color channels (R, G, B).
#
# • Separate the image into its three color channels (Red, Green, and Blue) and display them
# individually, labeling each channel as R, G, and B.{Using NumPy.}

# %%
img_np = np.array(img)


R = img_np.copy()
G = img_np.copy()
B = img_np.copy()

R[:, :, 1] = 0  # Set Green channel to 0
R[:, :, 2] = 0  # Set Blue channel to 0

G[:, :, 0] = 0  # Set Green channel to 0
G[:, :, 2] = 0  # Set Blue channel to 0

B[:, :, 0] = 0  # Set Green channel to 0
B[:, :, 1] = 0  # Set Blue channel to 0

display(R)
display(G)
display(B)
# Out:
# array([[[225,   0,   0],
#         [224,   0,   0],
#         [226,   0,   0],
#         ...,
#         [ 92,   0,   0],
#         [ 90,   0,   0],
#         [ 91,   0,   0]],
#
#        [[225,   0,   0],
#         [224,   0,   0],
#         [224,   0,   0],
#         ...,
#         [ 91,   0,   0],
#         [ 90,   0,   0],
#         [ 91,   0,   0]],
#
#        [[223,   0,   0],
#         [223,   0,   0],
#         [224,   0,   0],
#         ...,
#         [ 93,   0,   0],
#         [ 91,   0,   0],
#         [ 91,   0,   0]],
#
#        ...,
#
#        [[ 88,   0,   0],
#         [ 92,   0,   0],
#         [ 95,   0,   0],
#         ...,
#         [148,   0,   0],
#         [162,   0,   0],
#         [175,   0,   0]],
#
#        [[ 88,   0,   0],
#         [ 92,   0,   0],
#         [ 96,   0,   0],
#         ...,
#         [154,   0,   0],
#         [168,   0,   0],
#         [177,   0,   0]],
#
#        [[254,   0,   0],
#         [254,   0,   0],
#         [254,   0,   0],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0]]], dtype=uint8)
# array([[[  0, 127,   0],
#         [  0, 130,   0],
#         [  0, 130,   0],
#         ...,
#         [  0,  25,   0],
#         [  0,  23,   0],
#         [  0,  17,   0]],
#
#        [[  0, 130,   0],
#         [  0, 128,   0],
#         [  0, 130,   0],
#         ...,
#         [  0,  22,   0],
#         [  0,  22,   0],
#         [  0,  20,   0]],
#
#        [[  0, 128,   0],
#         [  0, 133,   0],
#         [  0, 129,   0],
#         ...,
#         [  0,  25,   0],
#         [  0,  22,   0],
#         [  0,  17,   0]],
#
#        ...,
#
#        [[  0,  23,   0],
#         [  0,  22,   0],
#         [  0,  26,   0],
#         ...,
#         [  0,  57,   0],
#         [  0,  68,   0],
#         [  0,  66,   0]],
#
#        [[  0,  26,   0],
#         [  0,  27,   0],
#         [  0,  26,   0],
#         ...,
#         [  0,  63,   0],
#         [  0,  71,   0],
#         [  0,  66,   0]],
#
#        [[  0, 254,   0],
#         [  0, 254,   0],
#         [  0, 254,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]]], dtype=uint8)
# array([[[  0,   0, 110],
#         [  0,   0, 106],
#         [  0,   0, 105],
#         ...,
#         [  0,   0,  64],
#         [  0,   0,  62],
#         [  0,   0,  56]],
#
#        [[  0,   0, 110],
#         [  0,   0, 104],
#         [  0,   0, 114],
#         ...,
#         [  0,   0,  64],
#         [  0,   0,  61],
#         [  0,   0,  63]],
#
#        [[  0,   0, 105],
#         [  0,   0, 114],
#         [  0,   0, 111],
#         ...,
#         [  0,   0,  67],
#         [  0,   0,  65],
#         [  0,   0,  61]],
#
#        ...,
#
#        [[  0,   0,  58],
#         [  0,   0,  58],
#         [  0,   0,  60],
#         ...,
#         [  0,   0,  78],
#         [  0,   0,  84],
#         [  0,   0,  78]],
#
#        [[  0,   0,  58],
#         [  0,   0,  61],
#         [  0,   0,  61],
#         ...,
#         [  0,   0,  83],
#         [  0,   0,  85],
#         [  0,   0,  77]],
#
#        [[  0,   0, 254],
#         [  0,   0, 254],
#         [  0,   0, 254],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]]], dtype=uint8)

# %% [markdown]
# 4. Modify the top 100 × 100 pixels to a value of 210 and display the resulting image:
#
# • Modify the pixel values of the top-left 100 × 100 region to have a value of 210 (which is a
# light gray color), and then display the modified image.

# %%
img_np[:100, 100] = 210
display(img_np)
# Out:
# array([[[225, 127, 110],
#         [224, 130, 106],
#         [226, 130, 105],
#         ...,
#         [ 92,  25,  64],
#         [ 90,  23,  62],
#         [ 91,  17,  56]],
#
#        [[225, 130, 110],
#         [224, 128, 104],
#         [224, 130, 114],
#         ...,
#         [ 91,  22,  64],
#         [ 90,  22,  61],
#         [ 91,  20,  63]],
#
#        [[223, 128, 105],
#         [223, 133, 114],
#         [224, 129, 111],
#         ...,
#         [ 93,  25,  67],
#         [ 91,  22,  65],
#         [ 91,  17,  61]],
#
#        ...,
#
#        [[ 88,  23,  58],
#         [ 92,  22,  58],
#         [ 95,  26,  60],
#         ...,
#         [148,  57,  78],
#         [162,  68,  84],
#         [175,  66,  78]],
#
#        [[ 88,  26,  58],
#         [ 92,  27,  61],
#         [ 96,  26,  61],
#         ...,
#         [154,  63,  83],
#         [168,  71,  85],
#         [177,  66,  77]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %% [markdown]
# 2.2 Exercise - 2:
# Complete all the Task.
#
# 1. Load and display a grayscale image.
#
# • Load a grayscale image using the Pillow library.
#
# • Display the grayscale image using matplotlib.

# %%
import matplotlib.pyplot as plt

# %%
img = Image.open('/content/drive/MyDrive/AI and ML/Workshop1/cameraman.png')
display(img)

# Using matplotlib
img_np = np.array(img)
plt.imshow(img_np, cmap='gray')
plt.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=512x512>

# %% [markdown]
# 2. Extract and display the middle section of the image (150 pixels).
#
# • Extract a 150 pixel section from the center of the image using NumPy array slicing.
#
# • Display this cropped image using matplotlib.

# %%
#Get image dimensions
height, width = img.size

#calculate center coordinates and cropping boundaries
center_x = width // 2
center_y = height // 2
start_x = center_x - 75 # 75 pixels on each side of the center
end_x = center_x + 75
start_y = center_y - 75
end_y = center_y + 75

# Extract the middle section using array slicing
middle_section = img_np[start_y:end_y, start_x:end_x]

#Display the cropped image
plt.imshow(middle_section, cmap='gray')#using cmap gray for grayscale image
plt.title('Middle Section (150*150)')
plt.axis('off')
plt.show()

# %% [markdown]
# 3. Apply a simple threshold to the image (e.g., set all pixel values below 100 to 0).
#
# • Apply a threshold to the grayscale image: set all pixel values below 100 to 0, and all values
# above 100 to 255 (creating a binary image).
#
# • Display the resulting binary image.

# %%
#Apply threshold
threshold_value = 100
binary_image = np.where(img_np < threshold_value, 0, 255)

#Display teh binary image
plt.imshow(binary_image, cmap='gray')
plt.title('Binary Image (Threshold = {})'.format(threshold_value))
plt.axis('off')
plt.show()

# %% [markdown]
# 4. Rotate the image 90 degrees clockwise and display the result.
#
# • Rotate the image by 90 degrees clockwise using the Pillow rotate method or by manipulating
# the image array.
#
# • Display the rotated image using matplotlib.

# %%
#Rotate the image 90 degress clcokwise
rotated_img = img.rotate(-90)

#Display the rotated image
plt.imshow(rotated_img, cmap='gray')
plt.title('Roatated Image (90 degress clockwise)')
plt.show()

# %% [markdown]
# 5. Convert the grayscale image to an RGB image.
#
# • Convert the grayscale image into an RGB image where the grayscale values are replicated
# across all three channels (R, G, and B).
#
# • Display the converted RGB image using matplotlib.

# %%
#Convert the image to a Numpy array
img_np = np.array(img)

#Stack the grayscal image  to create an RGB value
rgb_img_np = np.stack((img_np,)*3, axis=-1)
print(rgb_img_np.shape)

#Display the comverted RGB image
plt.imshow(rgb_img_np)
plt.title('converted RGB Image')
plt.axis('off')
plt.show()
# Out:
# (512, 512, 3)

# %% [markdown]
# **3      Image Compression and Decompression using PCA.**
#
# In this exercise, build a PCA from scratch using explained variance method for image compression task.
# You are expected to compute the necessary matrices from the scratch. Dataset: Use image of your
# choice.
#
# 1.   Load and Prepare Data:
#
# • Fetch an image of you choice.{If colour convert to grayscale}
#
# • Center the dataset - Standaridze the Data.
#
# • Calculate the covaraince matrix of the Standaridze data.

# %%
#convert to NUmpy array
image_array = np.array(img)
#get image dimensions
height, width = image_array.shape
#Reshape the image into a 2D array where each row represents a row of pixels
#this allows PCA to process eac row as an observation and find patterns across pixel intensisities
data = image_array.reshape(height, width)

#compute the mean of each column (feature)
mean = np.mean(data, axis = 0)
#subjeceted mean to center the data
centered_data = data - mean

#compute covariance matrix
cov_matrix = np.cov(centered_data, rowvar=False)
print(cov_matrix)
# Out:
# [[543.51861775 520.97947881 492.56189228 ... 452.37668175 465.56655914
#   469.92323569]
#  [520.97947881 515.55188585 504.98165744 ... 438.16924535 451.13798771
#   455.28722786]
#  [492.56189228 504.98165744 514.61175621 ... 415.396557   428.0037075
#   431.84547762]
#  ...
#  [452.37668175 438.16924535 415.396557   ... 694.40484344 701.46153376
#   705.1383317 ]
#  [465.56655914 451.13798771 428.0037075  ... 701.46153376 724.80795927
#   732.40163283]
#  [469.92323569 455.28722786 431.84547762 ... 705.1383317  732.40163283
#   741.0831091 ]]

# %% [markdown]
# 2. Eigen Decomposition and Identifying Principal Components:
# • Compute Eigen Values and Eigen Vectors.
#
# • Sort the eigenvalues in descending order and choose the top k eigenvectors corresponding to
# the highest eigenvalues.
#
# • Identify the Principal Components with the help of cumulative Sum plot.

# %%
#compute eigenvalues and eigenvectors
eigenvalues, eigenvectors = np.linalg.eigh(cov_matrix)
#sort eigenvalues and corresponding eigenvectors in descending order
sorted_indices = np.argsort(eigenvalues) [:: -1]
eigenvalues = eigenvalues [sorted_indices]
eigenvectors = eigenvectors [: , sorted_indices]

# %%
#plot the explained variance ratio
explained_variance_ratio = eigenvalues / np.sum(eigenvalues)
plt.plot(np.cumsum(explained_variance_ratio))
plt.title("Cumulative Explained variance")
plt.xlabel("Number of components")
plt.ylabel("Cumulative Explained Variance")
plt.grid(True)
plt.show()
k = 50 #choose k principal components
components = eigenvectors[: , : k]

# %% [markdown]
# 3. Reconstruction and Experiment:
#
# • Reconstruction: Transform the original data by multiplying it with the selected eigenvec-
# tors(PCs) to obtain a lower-dimensional representation.
#
# • Experiments: Pick Four different combination of principal components with various ex-
# plained variance value and compare the result.
#
# • Display the Results and Evaluate.

# %%
# Project the data onto the principal components
compressed_data = np.dot(centered_data, components)
print(compressed_data.shape)

#Reconstruction the image from compressed data
decompressed_data = np.dot(compressed_data, components.T) + mean

plt.figure(figsize =(12, 6))

#Original Image
plt.subplot(1, 3, 1)
plt.imshow(img)
plt.title("original Image")

#compressed Repersentation
plt.subplot(1, 3, 2)
plt.imshow(compressed_data)
plt.title(f" Compressed Image (k={k})")

#Decompressed Image
plt.subplot(1, 3, 3)
plt.imshow(decompressed_data)
plt.title("Decompressed Image")
plt.tight_layout()
plt.show()
# Out:
# (512, 50)

# %%
import matplotlib.pyplot as plt
import numpy as np

def compress_and_reconstruct(image_array, k):
  """Compress and reconstruct an image using PCA wit K components."""
  height, width = image_array.shape
  data = image_array.reshape(height, width)
  mean = np.mean(data, axis=0)
  centered_data = data - mean
  cov_matrix = np.cov(centered_data, rowvar=False)
  eigenvalues, eigenvectors = np.linalg.eigh(cov_matrix)
  sorted_indices = np.argsort(eigenvalues)[::-1]
  eigenvalues = eigenvalues[sorted_indices]
  eigenvectors = eigenvectors[:, sorted_indices]
  components = eigenvectors[:, :k]
  compressed_data = np.dot(centered_data, components)
  decompressed_data = np.dot(compressed_data, components.T) + mean
  return decompressed_data

image_array = np.array(img)
k_values = [20, 50, 100, 150, 200]  #different values of k

#create subplots for each k value
fig, axes = plt.subplots(1, len(k_values), figsize=(15,5))

for i, k in enumerate(k_values):

  reconstructed_image = compress_and_reconstruct(image_array, k)
  axes[i].imshow(reconstructed_image, cmap='gray')
  axes[i].set_title(f'k = {k}')
  axes[i].axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# **K=10:**
#
# The image is very blurry with almost no details. Important features and edges are hard to see.
#
# k=20 **bold text**
#
# A small improvement, but the image is still unclear. The basic shape is visible, but fine details are missing.
#
# k=50 **bold text**
#
# The image looks better, and main features start to appear. Some details are visible, but it's not fully sharp yet.
#
# k=100 **bold text**
#
# The image is much clearer. Most details are restored, and looks quite similar to the original, with only small imperfections.
#
# **k=200**
#
# The image is almost the same as the original. It has sharp details and looks nearly perfect.
